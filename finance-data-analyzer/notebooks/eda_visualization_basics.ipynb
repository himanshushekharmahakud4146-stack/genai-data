# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Matplotlib

# %% [markdown]
# **Matplotlib Basics**

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x**3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)
plt.title("Hello")
plt.xlabel('Chacha')
plt.ylabel("Chachi")
# Out:
# Text(0, 0.5, 'Chachi')

# %% [markdown]
# **Subplots In Matplotlib**

# %%
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)

# %% [markdown]
# **Object Oriented Way**

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(12,8),dpi= 100)
axis1 = fig.add_axes([.1,.1,.8,.8])
axis1.plot(x,y)
axis2 = fig.add_axes([.4,.3,.6,.4])
axis2.plot(x,y)

# %% [markdown]
# **Types Of Plots**

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x176f92710>,
#   <matplotlib.lines.Line2D at 0x176f92850>],
#  'caps': [<matplotlib.lines.Line2D at 0x176f92990>,
#   <matplotlib.lines.Line2D at 0x176f92ad0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x176f925d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x176f92c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x176f92d50>],
#  'means': []}

# %% [markdown]
# **Saving Plots**

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,.8,.8])
ax.plot(x,y)
# plt.savefig("basicPlot.png")

# %% [markdown]
# **Working with Images**

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread("../images/images.jpeg")
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(451.5), np.float64(677.5), np.float64(-0.5))

# %%
cropped_img = img[50:200, 100:300]  # crop: rows 50-200, cols 100-300
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %% [markdown]
# **Optional Designing**

# %%
plt.plot(x,y,color = 'pink')

# %%
xaxis = np.linspace(0,5,11)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# # 2. Distribution Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We use distribution plots to visualize the distribution of quantitative data.
#
# Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:
#
# * distplot/histplot
# * jointplot
# * pairplot
# * rugplot

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.displot(df['total_bill'],bins = 20,kde = True) # or 
# sns.histplot(df['total_bill'],bins = 20,kde = True)

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins = 20, kde = True)
plt.subplot(1,2,2)
sns.histplot(df['tip'],bins = 20, kde = True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.jointplot(x = 'total_bill',y = 'tip',data = df,kind= 'scatter')

# %%
sns.jointplot(x = 'total_bill',y = 'tip',data = df,kind= 'reg')

# %%
sns.pairplot(df,hue = 'sex')

# %%
sns.pairplot(df,hue = 'size',palette = 'rainbow')

# %%
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# # 3. Categorical Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:
#
# * boxplot
# * violinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot
#
# Let's go through examples of each!

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot( x = df['sex'],hue = df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x = df['sex'],y = df['total_bill'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# You can change the estimator object to your own function, that converts a vector to a scalar Mean (default): np.mean Median: np.median Sum: np.sum Count: len (to count the number of observations) Standard Deviation: np.std Minimum: np.min Maximum: np.max

# %%
import numpy as np
sns.barplot(x = df['sex'],y = df['tip'],estimator = np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x = df['tip'],y = df['day'],data = df,palette = 'rainbow')
# Out:
# /var/folders/z1/z0gs1hss3y70cwgr_fnknltw0000gn/T/ipykernel_3930/1465933209.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# **boxplot and violinplot**
#
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.violinplot(x = 'day',y = 'total_bill',data = df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # stripplot and swarmplot
#
# - The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# - The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
sns.stripplot(x = 'day',y = 'total_bill',data = df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day',y = 'total_bill',data = df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = 'tip',y = 'day',data = df)
sns.swarmplot(x = 'tip',y = 'day',data = df)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning:
#
# 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /opt/anaconda3/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning:
#
# 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# <Axes: xlabel='tip', ylabel='day'>
# /opt/anaconda3/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning:
#
# 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %% [markdown]
# # 4. Matrix Plot

# %% [markdown]
# #### Heat Map

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tipscorr = tips[['total_bill','tip','size']]
tipscorr
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tipscorr.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tipscorr.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ##### Cluster Map

# %%
sns.clustermap(tipscorr.corr())

# %% [markdown]
# ##### Pivot table Heat Map

# %%
pvtflights = flights.pivot_table(values = 'passengers',index = 'month',columns = 'year')
# Out:
# /var/folders/z1/z0gs1hss3y70cwgr_fnknltw0000gn/T/ipykernel_3930/647139072.py:1: FutureWarning:
#
# The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior

# %%
pvtflights
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# Dec    118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0  337.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0
# Jun    472.0  535.0
# Jul    548.0  622.0
# Aug    559.0  606.0
# Sep    463.0  508.0
# Oct    407.0  461.0
# Nov    362.0  390.0
# Dec    405.0  432.0

# %%
sns.heatmap(pvtflights)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# # 5. Regression Plot

# %% [markdown]
# **LmPlot()**

# %%
tips = sns.load_dataset("tips")

# %%
sns.lmplot(x = 'total_bill',y = 'tip' , data = tips)

# %%
sns.lmplot(x = 'total_bill',y = 'tip' , data = tips,hue = 'sex')

# %%
sns.lmplot(x = 'total_bill',y = 'tip' , data = tips,hue = 'sex',palette= 'rainbow')

# %%
sns.lmplot(x = 'total_bill',y = 'tip' , data = tips,hue = 'sex',palette= 'coolwarm',markers = ['o','v'],scatter_kws = {'s':100})

# %% [markdown]
# # 6. Plotly and Cufflinks

# %%
! pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.13/site-packages (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in /opt/anaconda3/lib/python3.13/site-packages (from plotly) (1.4.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.13/site-packages (from plotly) (1.17.0)

# %%
! pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in /opt/anaconda3/lib/python3.13/site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in /opt/anaconda3/lib/python3.13/site-packages (from cufflinks) (2.3.5)
# Requirement already satisfied: pandas>=0.19.2 in /opt/anaconda3/lib/python3.13/site-packages (from cufflinks) (2.3.3)
# Requirement already satisfied: plotly>=4.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from cufflinks) (4.14.3)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in /opt/anaconda3/lib/python3.13/site-packages (from cufflinks) (80.9.0)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from cufflinks) (9.7.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from cufflinks) (8.1.7)
# Requirement already satisfied: decorator>=4.3.2 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=5.3.0->cufflinks) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=5.3.0->cufflinks) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=5.3.0->cufflinks) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=5.3.0->cufflinks) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=5.3.0->cufflinks) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/lib/python3.13/site-packages (from jedi>=0.18.1->ipython>=5.3.0->cufflinks) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: retrying>=1.3.3 in /opt/anaconda3/lib/python3.13/site-packages (from plotly>=4.1.1->cufflinks) (1.4.2)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
from plotly.offline import iplot

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
